# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt('element_results.txt', skiprows=1)
# Out:
# [[-1.         -1.          1.          0.          0.          0.        ]
#  [-1.         -0.95918367  0.97959184  0.          0.          0.02040816]
#  [-1.         -0.91836735  0.95918367  0.          0.          0.04081633]
#  ...
#  [ 1.          0.91836735 -0.          0.04081633  0.95918367 -0.        ]
#  [ 1.          0.95918367 -0.          0.02040816  0.97959184 -0.        ]
#  [ 1.          1.          0.         -0.          1.         -0.        ]]

# %%
fig, ax = plt.subplots()
ax.scatter(data[:, 0], data[:, 1], c=data[:, 2])
fig.tight_layout()

# %%
fig, ax = plt.subplots()
ax.scatter(data[:, 0], data[:, 1], c=data[:, 3])
fig.tight_layout()
